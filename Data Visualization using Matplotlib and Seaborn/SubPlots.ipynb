# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]
y = [i * 2 for i in x]
z = [i ** 2 for i in x]

# %%
plt.subplot(1,2,1)
plt.plot(x,y)
plt.title("Double of x")


plt.subplot(1,2,2)
plt.plot(x,z)
plt.title("Square of x")
# Out:
# Text(0.5, 1.0, 'Square of x')
