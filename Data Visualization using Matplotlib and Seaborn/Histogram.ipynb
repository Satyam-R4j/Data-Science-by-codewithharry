# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data = [14, 89,98,73,92,87,6,23,25,85,
        96,56,65,78,21,53,63,97,69,92,
        62,82,85,56,13,59,50,19,17,53,
        20,12,19,5,78,94,35,75,82,79,
        10,34,24,10,68,55,88,29,95,47]

# %%
plt.hist(data,bins=5,edgecolor='black')
plt.axvline(np.mean(age), color='red', linestyle='--
plt.xlabel("marks")
plt.ylabel("Frequency")
plt.tight_layout()
