# %%
import tensorflow as tf

# %%
import matplotlib.pyplot as plt

# %%
(x_train,x_test),(y_train,y_test) = tf.keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
plt.figure(figsize=(10,4))
for i in range(10):
    plt.subplot(1,10,i+1)
    plt.imshow(x_train[i], cmap="gray")
    plt.axis("off")
    plt.title(str(y_train[i]),fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\satya\AppData\Local\Temp\ipykernel_15456\3899410111.py:7: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
